# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from statsmodels.tsa.stattools import adfuller, kpss

from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

from statsmodels.tsa.api import ARIMA

import pmdarima as pm

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## KEY CONCEPTS
#
# 1. `Autocorrelation`
# * What is the difference between correlation and autocorrelation? => autocorrelation is analogous to correlation, but instead of describing the relationship between 2 different variables, it describes a relationship between a variable and lagged values of that variable instead. (2 variables from a same time series, auto = self)
#
# 2. `ACF plot`, `PACF plot`
# * The ACF plot reflects both the direct and indirect interplays between the lags in the Time Series. It is useful to identify the optimal order of the pure AR model.
# * The PACF plot, which controls the indirect effects, is useful to identify the order of the pure MA model.
# * When combining the AR and MA model, the effects are mixed, hence more difficult to identify using ACF/PACF plots.
#
# 3. `Stationarity`
# * The weak-sense definition of stationarity is covariance stationarity: the 1st and 2nd moments, as well as the ACF of the Time Series remain stable. The models are less useful for future predictions if these parameters are dynamic.
#
# 4. `Differencing`
# * This is one of the common technique to make the Time Series stationary.
#
# 5. `ARIMA`
# * ARIMA = ARMA + Differencing.
# * Integration (I):\
# a) The "Integrated" part of ARIMA handles non-stationary data by differencing.\
# b) Differencing involves subtracting the previous value from the current value.\
# c) This process removes trends and makes the series stationary.
#
# * ARIMA(p, d, q):\
# a) p: Order of the AR part.\
# b) d: Order of differencing required to make the series stationary.\
# c) q: Order of the MA part.
#
# * Special cases:\
# a) ARIMA(p, 0, 0) = AR(p) / ARMA (p, 0): Pure autoregressive model.\
# b) ARIMA(0, 0, q) = MA(q) / ARMA (0, q): Pure moving average model.\
# c) ARIMA(0, d, 0) = I(d): Purely differenced series, like a random walk.
#
# * Random walk: ARIMA(0, 1, 0) and I(1) is the random walk.
#
# 6. `SARIMA`
# * Stock prices don’t typically have seasonality, but stock prices don’t comprise all financial data. e.g. weather (seasons) affect real estate purchase.
# * ARIMA with the “I” component can handle trends by differencing, but it doesn’t handle seasonality well on its own, which is why seasonal versions of ARIMA (SARIMA) are used for time series with strong seasonal components.
# * SARIMA includes both non-seasonal and seasonal components.
# * The model is typically denoted with 6 parameters in total: SARIMA{(p, d, q) *  (P, D, Q)[m]}, where:
# > p: Non-seasonal autoregressive order (AR).\
# > d: Non-seasonal differencing order (I).\
# > q: Non-seasonal moving average order (MA).\
# > P: Seasonal autoregressive order (SAR).\
# > D: Seasonal differencing order (seasonal I).\
# > Q: Seasonal moving average order (SMA).\
# > m: The number of time periods per season (e.g., 12 for monthly data with yearly seasonality).
#
# * This implies that the SARIMA model is the multiplication of the non-seasonal and the seasonal components. (P, D, Q)m is the pure seasonal ARIMA model where m is seasonal frequency requires D seasonal differencing, has P AR terms at seasonal lags and Q MA terms at seasonal lags.
#
# * ARIMA can still give a decent forecast without including the seasonaility, but using SARIMA can lead to a better model.

# %% [markdown]
# ## ARIMA using eye-balling

# %%
df1 = pd.read_csv('airline_passengers.csv', index_col =  'Month', parse_dates = True)
df1.head()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %%
df1.plot(figsize = (10, 5))
plt.grid(True, alpha = 0.3);

# %%
# Def a function to check stationarity for further works

def check_stationarity(series):
    """
    Check the stationarity of a time series using ADF and KPSS tests.
    ADF H0: non-stationary -> high p-value (> 0.05) = non-stationary
    KPSS H0: stationary -> low p-value (< 0.05) = non-stationary
    """
    # Perform Augmented Dickey-Fuller test
    adf_result = adfuller(series.dropna())
    adf_p_value = adf_result[1]  # Extract p-value from ADF test; if we want test statistic then it is [0]

    # Perform KPSS test
    kpss_result = kpss(series.dropna(), regression='c')
    kpss_p_value = kpss_result[1]  # Extract p-value from KPSS test

    # ADF Test Conclusion
    if adf_p_value < 0.05:
        adf_conclusion = "The series is stationary based on the ADF test (p-value < 0.05)."
    else:
        adf_conclusion = "The series is non-stationary based on the ADF test (p-value >= 0.05)."

    # KPSS Test Conclusion
    if kpss_p_value < 0.05:
        kpss_conclusion = "The series is non-stationary based on the KPSS test (p-value < 0.05)."
    else:
        kpss_conclusion = "The series is stationary based on the KPSS test (p-value >= 0.05)."

    # Print test results and conclusions
    print(f"ADF Test: p-value = {adf_p_value:.5f}")
    print(adf_conclusion)
    print(f"KPSS Test: p-value = {kpss_p_value:.5f}")
    print(kpss_conclusion)

    # return {'ADF': adf_p_value, 'ADF Conclusion': adf_conclusion, 'KPSS': kpss_p_value, 'KPSS Conclusion': kpss_conclusion}

# %%
check_stationarity(df1.Passengers)
# Out:
# ADF Test: p-value = 0.99188
# The series is non-stationary based on the ADF test (p-value >= 0.05).
# KPSS Test: p-value = 0.01000
# The series is non-stationary based on the KPSS test (p-value < 0.05).

# %% [markdown]
# * So we need to apply Differencing. Let's def another one to check the proper order.

# %%
def difference_until_pass_kpss(time_series, max_diff=3, significance_level=0.05):
    """
    Perform differencing on the time series until it passes the KPSS test for stationarity
    or until the maximum number of differencing steps (max_diff) is reached.

    Parameters:
    - time_series: The original time series (pandas Series).
    - max_diff: The maximum number of differencing steps to apply.
    - significance_level: The significance level for the KPSS test (default is 0.05).

    Prints:
    - A message indicating whether the series became stationary or failed the KPSS test.
    """

    # Sub-function to perform the KPSS test
    def kpss_test(ts):
        """Run KPSS test on the time series and return whether it passes the test (stationary)."""
        statistic, p_value, _, _ = kpss(ts, regression='c', nlags="auto")
        return p_value > significance_level  # If p-value is greater than significance level, the series is stationary

    d = 0  # Initialize differencing count
    diff_series = time_series.copy()

    # Loop to difference and test for stationarity using KPSS
    while d <= max_diff:
        if kpss_test(diff_series):
            print(f"Series became stationary after {d} differencing(s).")
            break  # Stop further execution if series is stationary
        else:
            d += 1
            if d <= max_diff:
                diff_series = diff_series.diff().dropna()  # Apply differencing internally

    # If the loop ends without the series becoming stationary
    if d > max_diff:
        print(f"The series fails the KPSS test at d = {max_diff}.")

# %%
difference_until_pass_kpss(df1.Passengers)
# Out:
# Series became stationary after 1 differencing(s).

# %% [markdown]
# * So d = 1 is a good candidate in the optimal model.
# * Let apply Differencing once, then use ACF and PACF to see some patterns if any.

# %%
df1['Passengers_Diff'] = df1.Passengers.diff()

# %%
plot_acf(df1['Passengers_Diff'].dropna());

# %%
plot_pacf(df1['Passengers_Diff'].dropna());

# %% [markdown]
# * Lag 12 is a good candidate to set the orders for AR and MA components.
# * Because in theory MA reflects very-short movements, thus we can choose 12 as the order of the AR component.
# * Let's def a function to apply ARIMA for future works.

# %%
def arima_split(df: pd.DataFrame, data_col: str, Ntest: int, freq =  'MS', order=(0, 0, 0), y_name='Time Series'):
    """
    Plot the actual, fitted, and forecasted values with confidence intervals.
    
    Args:
        df: DataFrame containing the time series data.
        data_col: Name of the column with the time series data.
        Ntest: Number of future points to be forecasted and separated from the training data.
        order: ARIMA model order (p, d, q).
        y_name: Specifies the name for plotting (y-axis and title).
        
    Returns:
        train_actual: Actual values from the training set.
        train_pred: Fitted values from the ARIMA model on the training set.
        test_actual: Actual values from the test set.
        test_forecast: Forecasted values from the ARIMA model on the test set.
    """
    df.index.freq = freq # setting the frequency facilitates accuracy
    
    # Separate training and test data based on the number of test points
    train = df.iloc[:-Ntest]
    test = df.iloc[-Ntest:]

    # Run ARIMA model
    model = ARIMA(train[data_col], order=order)
    arima_result = model.fit()

    # Plot the actual values
    fig, ax = plt.subplots(figsize=(15, 6))
    ax.plot(df.index, df[data_col], label='Actual values', color='orange', alpha = 0.5)

    # Plot the fitted values on the training set
    train_prediction = arima_result.predict(start=train.index[0], end=train.index[-1])
    ax.plot(train.index, train_prediction, color='green', label='Fitted values')

    # Forecast the test set values
    test_forecast = arima_result.get_forecast(steps=Ntest)
    forecast = test_forecast.predicted_mean  # extract mean from the forecast object
    conf_int = test_forecast.conf_int()  # extract confidence interval from the forecast object
    lower, upper = conf_int.iloc[:, 0], conf_int.iloc[:, 1]

    # Plot forecast and confidence interval
    ax.plot(test.index, forecast, label='Forecast values', color='blue')
    ax.fill_between(test.index, lower, upper, color='grey', alpha=0.3, label='Confidence Interval')

    ax.set_title(f'ARIMA{order} ({y_name})', color='darkred')
    ax.set_ylabel(y_name)
    ax.legend(loc='best')
    plt.grid(True, alpha=0.3)
    plt.show()

    # Store actual and forecasted values for both train and test sets
    train_actual = train[data_col]  # Actual values in the training set
    train_pred = train_prediction   # Fitted (predicted) values for the training set
    test_actual = test[data_col]    # Actual values in the test set
    test_forecast = forecast        # Forecasted values for the test set

    # Return train and test values for further evaluation (to calculate R², etc.)
    return train_actual, train_pred, test_actual, test_forecast

# %%
train_actual1, train_pred1, test_actual1, test_forecast1 = arima_split(df1.dropna(), 'Passengers', Ntest = 12, freq = 'MS',
                                                                   order=(12, 1, 0), y_name='Number of Passengers')

# Ntest = 12 is just an abtrary number for demonstration

# %% [markdown]
# * Looks fine. Let's def another function to calculate performance metrics.

# %%
def evaluate_model(y_true, y_pred, is_logged = False):
    """
    Calculate common metrics to evaluate a model.
    
    Args:
        y_true: Array or list of actual values.
        y_pred: Array or list of predicted values.
        is_logged: if the data has been transformed by log, then reverting back to the original unit
        
    Returns:
        A dictionary with common metrics: MAE, MSE, RMSE, MAPE, R².
    """
    if is_logged == True:
        y_true = np.exp(y_true)
        y_pred = np.exp(y_pred)
    else:
        y_true =  y_true
        y_pred =  y_pred
    
    # Mean Absolute Error (MAE)
    mae = mean_absolute_error(y_true, y_pred)
    
    # Mean Squared Error (MSE)
    mse = mean_squared_error(y_true, y_pred)
    
    # Root Mean Squared Error (RMSE)
    rmse = np.sqrt(mse)
    
    # Mean Absolute Percentage Error (MAPE)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    
    # R-squared (R²)
    r2 = r2_score(y_true, y_pred)
    
    # Return the metrics in a dictionary
    return {
        'MAE': round(mae,6),
        'MSE': round(mse,6),
        'RMSE': round(rmse,6),
        'MAPE': round(mape,6),
        'R²': round(r2, 6) }

# %%
evaluate_model(train_actual1, train_pred1)
# Out:
# {'MAE': 9.345064,
#  'MSE': 220.687788,
#  'RMSE': 14.855564,
#  'MAPE': 4.373756,
#  'R²': 0.980287}

# %%
evaluate_model(test_actual1, test_forecast1)
# Out:
# {'MAE': 13.782375,
#  'MSE': 306.017228,
#  'RMSE': 17.493348,
#  'MAPE': 2.939094,
#  'R²': 0.944757}

# %% [markdown]
# * Now let's move to using Auto SARIMA to see if we can get a better model.

# %% [markdown]
# ## Auto SARIMA

# %%
df2 = pd.read_csv('airline_passengers.csv', index_col =  'Month', parse_dates = True) # still this dataset

# %% [markdown]
# * Using the ACF, PACF above as a skimming test, m = 12 is a good candidate for the Auto Seasonal ARIMA model.

# %%
def auto_sarima_split(df: pd.DataFrame, data_col: str, Ntest: int, freq =  'MS',
                     seasonal=True, m=12, 
                     stepwise=True, y_name='Number of Passengers'):
    """
    Function to perform Auto SARIMA(p, d, q)(P, D, Q)[m] with train-test split, where Ntest is the number
    of steps for test. Outputs model summary and a plot of actual vs fitted vs forecast.
    
    Parameters:
    - df: DataFrame containing the time series data
    - data_col: Column name of the time series data in the DataFrame
    - Ntest: Number of test periods to split from the data
    - seasonal: Boolean indicating whether to fit a seasonal ARIMA model
    - m: Number of periods in a seasonal cycle
    - stepwise: Boolean; if False, do full grid search
    - y_name: Label for the y-axis in the plot
    
    Outputs:
    - Model summary
    - Plot of actual, fitted, and forecasted values
    - Returns the actual and forecasted values for further evaluation
    """
    df.index.freq = freq

    # Split the data into train and test sets
    train = df.iloc[:-Ntest]
    test = df.iloc[-Ntest:]
    
    # Fit the Auto ARIMA model
    model = pm.auto_arima(train[data_col], 
                          trace=True, 
                          suppress_warnings=True,
                          seasonal=seasonal, 
                          m=m, 
                          stepwise=stepwise,
                          max_p= 15, max_q=10, max_order=25)
    
    # Output the model summary
    print(model.summary())
    
    # Plot the actual values
    fig, ax = plt.subplots(figsize=(15, 7))
    ax.plot(df.index, df[data_col], label='Actual data', color='orange', alpha = 0.5)

    # Get the differencing order `d` from the model
    d = model.order[1]  # Differencing order

    # Get in-sample fitted values (train predictions)
    train_prediction = model.predict_in_sample(start=d, end=len(train) - 1)

    # Plot fitted values for training data
    ax.plot(train.index[d:], train_prediction, label='Fitted values', color='green')

    # Make forecast for the test period
    test_forecast, confint = model.predict(n_periods=Ntest, return_conf_int=True)

    # Plot forecasted values for test period
    ax.plot(test.index, test_forecast, label='Forecast', color='blue')
    
    # Plot confidence interval
    ax.fill_between(test.index, confint[:, 0], confint[:, 1], color='grey', alpha=0.3)

    # Add plot labels and legend
    ax.legend(loc='best')
    ax.set_title(f'Auto ARIMA ({y_name})', color='darkred')
    ax.set_ylabel(y_name)
    ax.grid(True, alpha=0.3)
    
    # Show the plot
    plt.show()

    # Adjust `actual_train` to match the length of `train_prediction`
    actual_train = train[data_col].iloc[d:]  # Start from index `d` to match `train_prediction`
    
    # Return actual train, train predictions, actual test values, and test forecasts for evaluation
    actual_test = test[data_col]
    return actual_train, train_prediction, actual_test, test_forecast

# %%
train_actual2, train_pred2, test_actual2, test_pred2 = auto_sarima_split(df2.dropna(), 'Passengers', 
                                                                            Ntest = 12,
                                                                            seasonal=True, m=12, 
                                                                            y_name='Number of Passengers')
# Here the Auto SARIMA model will identify the optimal d so we don't need to apply differencing
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=1022.234, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=906.857, Time=0.15 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=963.555, Time=0.19 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=1192.711, Time=0.01 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=907.180, Time=0.02 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=908.543, Time=0.44 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=0.39 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=907.120, Time=0.14 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=1.17 sec
#  ARIMA(0,0,0)(1,1,0)[12] intercept   : AIC=1021.611, Time=0.09 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=906.396, Time=0.24 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=906.075, Time=0.07 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=906.713, Time=0.15 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(3,0,0)(0,1,0)[12] intercept   : AIC=905.686, Time=0.05 sec
#  ARIMA(3,0,0)(1,1,0)[12] intercept   : AIC=906.124, Time=0.32 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=906.388, Time=0.22 sec
#  ARIMA(3,0,0)(1,1,1)[12] intercept   : AIC=906.035, Time=0.60 sec
#  ARIMA(4,0,0)(0,1,0)[12] intercept   : AIC=907.453, Time=0.11 sec
#  ARIMA(3,0,1)(0,1,0)[12] intercept   : AIC=907.583, Time=0.11 sec
#  ARIMA(2,0,1)(0,1,0)[12] intercept   : AIC=906.399, Time=0.07 sec
#  ARIMA(4,0,1)(0,1,0)[12] intercept   : AIC=909.320, Time=0.10 sec
#  ARIMA(3,0,0)(0,1,0)[12]             : AIC=911.907, Time=0.02 sec
#
# Best model:  ARIMA(3,0,0)(0,1,0)[12] intercept
# Total fit time: 5.821 seconds
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  132
# Model:             SARIMAX(3, 0, 0)x(0, 1, 0, 12)   Log Likelihood                -447.843
# Date:                            Sat, 12 Oct 2024   AIC                            905.686
# Time:                                    15:03:41   BIC                            919.623
# Sample:                                01-01-1949   HQIC                           911.346
#                                      - 12-01-1959
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      5.5341      2.007      2.757      0.006       1.600       9.468
# ar.L1          0.7049      0.095      7.393      0.000       0.518       0.892
# ar.L2          0.2574      0.131      1.968      0.049       0.001       0.514
# ar.L3         -0.1434      0.107     -1.338      0.181      -0.354       0.067
# sigma2       101.0969     12.818      7.887      0.000      75.974     126.220
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 2.83
# Prob(Q):                              0.96   Prob(JB):                         0.24
# Heteroskedasticity (H):               1.41   Skew:                            -0.14
# Prob(H) (two-sided):                  0.29   Kurtosis:                         3.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# * The best Auto SARIMA model using m = 12 is (3, 0, 0)(0, 1, 0)[12]

# %%
evaluate_model(train_actual2, train_pred2)
# Out:
# {'MAE': 16.01031,
#  'MSE': 949.901688,
#  'RMSE': 30.820475,
#  'MAPE': 9.796279,
#  'R²': 0.915811}

# %%
evaluate_model(test_actual2, test_pred2)
# Out:
# {'MAE': 14.898208,
#  'MSE': 343.600677,
#  'RMSE': 18.536469,
#  'MAPE': 3.097562,
#  'R²': 0.937972}

# %% [markdown]
# * In terms of R2, these are not superior compared to the ARIMA(12, 1, 0) model above.

# %%
df2['LogPassengers'] = np.log(df2.Passengers) # Let's try some log transformation

# %%
difference_until_pass_kpss(df2['LogPassengers']) # just to check
# Out:
# Series became stationary after 1 differencing(s).

# %%
train_actual3, train_pred3, test_actual3, test_pred3 =  auto_sarima_split(df2.dropna(), 'LogPassengers', 
                                                                            Ntest = 12, 
                                                                            seasonal=True, m=12, 
                                                                            y_name='Log Passengers')

# Try again with log data to see if we can improve the model
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=-440.388, Time=0.79 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=-317.949, Time=0.03 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=-433.027, Time=0.55 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=-383.189, Time=0.33 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=-134.983, Time=0.01 sec
#  ARIMA(2,0,2)(0,1,1)[12] intercept   : AIC=-444.326, Time=0.91 sec
#  ARIMA(2,0,2)(0,1,0)[12] intercept   : AIC=-414.783, Time=0.22 sec
#  ARIMA(2,0,2)(0,1,2)[12] intercept   : AIC=-442.330, Time=1.70 sec
#  ARIMA(2,0,2)(1,1,0)[12] intercept   : AIC=-436.714, Time=0.97 sec
#  ARIMA(2,0,2)(1,1,2)[12] intercept   : AIC=inf, Time=1.89 sec
#  ARIMA(1,0,2)(0,1,1)[12] intercept   : AIC=-445.572, Time=0.56 sec
#  ARIMA(1,0,2)(0,1,0)[12] intercept   : AIC=-414.732, Time=0.09 sec
#  ARIMA(1,0,2)(1,1,1)[12] intercept   : AIC=-439.509, Time=0.67 sec
#  ARIMA(1,0,2)(0,1,2)[12] intercept   : AIC=-443.555, Time=1.25 sec
#  ARIMA(1,0,2)(1,1,0)[12] intercept   : AIC=-437.466, Time=0.53 sec
#  ARIMA(1,0,2)(1,1,2)[12] intercept   : AIC=inf, Time=1.51 sec
#  ARIMA(0,0,2)(0,1,1)[12] intercept   : AIC=-416.893, Time=0.79 sec
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=-447.284, Time=0.56 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=-416.167, Time=0.12 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=-445.194, Time=0.54 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=-445.312, Time=1.14 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=-439.764, Time=0.70 sec
#  ARIMA(1,0,1)(1,1,2)[12] intercept   : AIC=inf, Time=1.50 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=-442.847, Time=0.31 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=-446.293, Time=0.66 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=-327.548, Time=0.16 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=-448.052, Time=0.63 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=-417.188, Time=0.07 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=-441.234, Time=0.70 sec
#  ARIMA(2,0,0)(0,1,2)[12] intercept   : AIC=-446.060, Time=1.60 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=-440.423, Time=0.66 sec
#  ARIMA(2,0,0)(1,1,2)[12] intercept   : AIC=inf, Time=1.49 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=-446.261, Time=0.48 sec
#  ARIMA(3,0,1)(0,1,1)[12] intercept   : AIC=-444.359, Time=0.67 sec
#  ARIMA(2,0,0)(0,1,1)[12]             : AIC=-440.545, Time=0.34 sec
#
# Best model:  ARIMA(2,0,0)(0,1,1)[12] intercept
# Total fit time: 25.137 seconds
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  132
# Model:             SARIMAX(2, 0, 0)x(0, 1, [1], 12)   Log Likelihood                 229.026
# Date:                              Sat, 12 Oct 2024   AIC                           -448.052
# Time:                                      15:04:06   BIC                           -434.114
# Sample:                                  01-01-1949   HQIC                          -442.392
#                                        - 12-01-1959
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0193      0.009      2.155      0.031       0.002       0.037
# ar.L1          0.6001      0.083      7.269      0.000       0.438       0.762
# ar.L2          0.2417      0.085      2.853      0.004       0.076       0.408
# ma.S.L12      -0.5672      0.105     -5.418      0.000      -0.772      -0.362
# sigma2         0.0012      0.000      8.191      0.000       0.001       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 6.09
# Prob(Q):                              1.00   Prob(JB):                         0.05
# Heteroskedasticity (H):               0.36   Skew:                             0.07
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.09
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
evaluate_model(train_actual3, train_pred3, is_logged = True) # note the parameters is_logged
# Out:
# {'MAE': 17.742597,
#  'MSE': 1524.951506,
#  'RMSE': 39.050627,
#  'MAPE': 11.516609,
#  'R²': 0.864844}

# %%
evaluate_model(test_actual3, test_pred3, is_logged = True)
# Out:
# {'MAE': 18.32176,
#  'MSE': 531.033662,
#  'RMSE': 23.044168,
#  'MAPE': 3.948949,
#  'R²': 0.904136}

# %% [markdown]
# * So they are not superior compared to our very first model ARIMA(12, 1, 0).

# %%
train_actual4, train_pred4, test_actual4, test_pred4 = auto_sarima_split(df2, 'Passengers', 
                                                                            Ntest = 12, 
                                                                            seasonal=False,
                                                                            stepwise = False, # Full Grid Search
                                                                            y_name='Passengers')
# Let's remove seasonal assumption and try Full Grid Search on both non-logged and logged data
# Out:
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1277.589, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1264.738, Time=0.03 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1262.608, Time=0.03 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(0,1,5)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(0,1,6)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(0,1,7)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(0,1,8)(0,0,0)[0] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(0,1,9)(0,0,0)[0] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(0,1,10)(0,0,0)[0] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1268.313, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1258.440, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(1,1,5)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(1,1,6)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(1,1,7)(0,0,0)[0] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(1,1,8)(0,0,0)[0] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(1,1,9)(0,0,0)[0] intercept   : AIC=inf, Time=0.36 sec
#  ARIMA(1,1,10)(0,0,0)[0] intercept   : AIC=inf, Time=0.67 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=1263.896, Time=0.04 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1218.683, Time=0.07 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(2,1,5)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(2,1,6)(0,0,0)[0] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(2,1,7)(0,0,0)[0] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(2,1,8)(0,0,0)[0] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(2,1,9)(0,0,0)[0] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(2,1,10)(0,0,0)[0] intercept   : AIC=inf, Time=0.73 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=1261.216, Time=0.05 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(3,1,5)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(3,1,6)(0,0,0)[0] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(3,1,7)(0,0,0)[0] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(3,1,8)(0,0,0)[0] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(3,1,9)(0,0,0)[0] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(3,1,10)(0,0,0)[0] intercept   : AIC=inf, Time=0.67 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=1254.439, Time=0.03 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=1245.588, Time=0.09 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(4,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(4,1,5)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(4,1,6)(0,0,0)[0] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(4,1,7)(0,0,0)[0] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(4,1,8)(0,0,0)[0] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(4,1,9)(0,0,0)[0] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(4,1,10)(0,0,0)[0] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=1256.151, Time=0.05 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=1247.185, Time=0.15 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(5,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(5,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(5,1,5)(0,0,0)[0] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(5,1,6)(0,0,0)[0] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(5,1,7)(0,0,0)[0] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(5,1,8)(0,0,0)[0] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(5,1,9)(0,0,0)[0] intercept   : AIC=inf, Time=0.39 sec
#  ARIMA(5,1,10)(0,0,0)[0] intercept   : AIC=inf, Time=0.54 sec
#  ARIMA(6,1,0)(0,0,0)[0] intercept   : AIC=1252.415, Time=0.04 sec
#  ARIMA(6,1,1)(0,0,0)[0] intercept   : AIC=1246.387, Time=0.15 sec
#  ARIMA(6,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(6,1,3)(0,0,0)[0] intercept   : AIC=1210.869, Time=0.14 sec
#  ARIMA(6,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(6,1,5)(0,0,0)[0] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(6,1,6)(0,0,0)[0] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(6,1,7)(0,0,0)[0] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(6,1,8)(0,0,0)[0] intercept   : AIC=inf, Time=0.33 sec
#  ARIMA(6,1,9)(0,0,0)[0] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(6,1,10)(0,0,0)[0] intercept   : AIC=inf, Time=0.57 sec
#  ARIMA(7,1,0)(0,0,0)[0] intercept   : AIC=1252.659, Time=0.09 sec
#  ARIMA(7,1,1)(0,0,0)[0] intercept   : AIC=1212.214, Time=0.22 sec
#  ARIMA(7,1,2)(0,0,0)[0] intercept   : AIC=1215.269, Time=0.14 sec
#  ARIMA(7,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(7,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(7,1,5)(0,0,0)[0] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(7,1,6)(0,0,0)[0] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(7,1,7)(0,0,0)[0] intercept   : AIC=1147.455, Time=0.31 sec
#  ARIMA(7,1,8)(0,0,0)[0] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(7,1,9)(0,0,0)[0] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(7,1,10)(0,0,0)[0] intercept   : AIC=inf, Time=0.66 sec
#  ARIMA(8,1,0)(0,0,0)[0] intercept   : AIC=1210.583, Time=0.22 sec
#  ARIMA(8,1,1)(0,0,0)[0] intercept   : AIC=1178.114, Time=0.24 sec
#  ARIMA(8,1,2)(0,0,0)[0] intercept   : AIC=1180.440, Time=0.20 sec
#  ARIMA(8,1,3)(0,0,0)[0] intercept   : AIC=1171.032, Time=0.21 sec
#  ARIMA(8,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(8,1,5)(0,0,0)[0] intercept   : AIC=1143.693, Time=0.26 sec
#  ARIMA(8,1,6)(0,0,0)[0] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(8,1,7)(0,0,0)[0] intercept   : AIC=1141.411, Time=0.29 sec
#  ARIMA(8,1,8)(0,0,0)[0] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(8,1,9)(0,0,0)[0] intercept   : AIC=1120.223, Time=0.44 sec
#  ARIMA(8,1,10)(0,0,0)[0] intercept   : AIC=inf, Time=0.71 sec
#  ARIMA(9,1,0)(0,0,0)[0] intercept   : AIC=1206.774, Time=0.25 sec
#  ARIMA(9,1,1)(0,0,0)[0] intercept   : AIC=1177.544, Time=0.24 sec
#  ARIMA(9,1,2)(0,0,0)[0] intercept   : AIC=1179.061, Time=0.25 sec
#  ARIMA(9,1,3)(0,0,0)[0] intercept   : AIC=1144.651, Time=0.27 sec
#  ARIMA(9,1,4)(0,0,0)[0] intercept   : AIC=1147.698, Time=0.29 sec
#  ARIMA(9,1,5)(0,0,0)[0] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(9,1,6)(0,0,0)[0] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(9,1,7)(0,0,0)[0] intercept   : AIC=inf, Time=0.38 sec
#  ARIMA(9,1,8)(0,0,0)[0] intercept   : AIC=inf, Time=0.39 sec
#  ARIMA(9,1,9)(0,0,0)[0] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(9,1,10)(0,0,0)[0] intercept   : AIC=inf, Time=0.72 sec
#  ARIMA(10,1,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(10,1,1)(0,0,0)[0] intercept   : AIC=1101.963, Time=0.27 sec
#  ARIMA(10,1,2)(0,0,0)[0] intercept   : AIC=1055.443, Time=0.33 sec
#  ARIMA(10,1,3)(0,0,0)[0] intercept   : AIC=1055.330, Time=0.35 sec
#  ARIMA(10,1,4)(0,0,0)[0] intercept   : AIC=1051.654, Time=0.34 sec
#  ARIMA(10,1,5)(0,0,0)[0] intercept   : AIC=1060.403, Time=0.37 sec
#  ARIMA(10,1,6)(0,0,0)[0] intercept   : AIC=1030.145, Time=0.42 sec
#  ARIMA(10,1,7)(0,0,0)[0] intercept   : AIC=1027.914, Time=0.42 sec
#  ARIMA(10,1,8)(0,0,0)[0] intercept   : AIC=1027.751, Time=0.46 sec
#  ARIMA(10,1,9)(0,0,0)[0] intercept   : AIC=1071.294, Time=0.48 sec
#  ARIMA(10,1,10)(0,0,0)[0] intercept   : AIC=1034.822, Time=0.61 sec
#  ARIMA(11,1,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.38 sec
#  ARIMA(11,1,1)(0,0,0)[0] intercept   : AIC=1075.068, Time=0.54 sec
#  ARIMA(11,1,2)(0,0,0)[0] intercept   : AIC=1039.494, Time=0.48 sec
#  ARIMA(11,1,3)(0,0,0)[0] intercept   : AIC=1036.267, Time=0.56 sec
#  ARIMA(11,1,4)(0,0,0)[0] intercept   : AIC=1034.868, Time=0.52 sec
#  ARIMA(11,1,5)(0,0,0)[0] intercept   : AIC=1033.511, Time=0.50 sec
#  ARIMA(11,1,6)(0,0,0)[0] intercept   : AIC=1028.044, Time=0.55 sec
#  ARIMA(11,1,7)(0,0,0)[0] intercept   : AIC=1029.899, Time=0.65 sec
#  ARIMA(11,1,8)(0,0,0)[0] intercept   : AIC=1025.964, Time=0.76 sec
#  ARIMA(11,1,9)(0,0,0)[0] intercept   : AIC=1036.119, Time=0.64 sec
#  ARIMA(11,1,10)(0,0,0)[0] intercept   : AIC=1036.356, Time=0.74 sec
#  ARIMA(12,1,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.60 sec
#  ARIMA(12,1,1)(0,0,0)[0] intercept   : AIC=1022.779, Time=0.50 sec
#  ARIMA(12,1,2)(0,0,0)[0] intercept   : AIC=1020.062, Time=0.58 sec
#  ARIMA(12,1,3)(0,0,0)[0] intercept   : AIC=1019.725, Time=0.60 sec
#  ARIMA(12,1,4)(0,0,0)[0] intercept   : AIC=1021.382, Time=0.62 sec
#  ARIMA(12,1,5)(0,0,0)[0] intercept   : AIC=1021.539, Time=0.63 sec
#  ARIMA(12,1,6)(0,0,0)[0] intercept   : AIC=1023.299, Time=0.67 sec
#  ARIMA(12,1,7)(0,0,0)[0] intercept   : AIC=1024.659, Time=0.75 sec
#  ARIMA(12,1,8)(0,0,0)[0] intercept   : AIC=1026.618, Time=0.75 sec
#  ARIMA(12,1,9)(0,0,0)[0] intercept   : AIC=1029.489, Time=0.77 sec
#  ARIMA(12,1,10)(0,0,0)[0] intercept   : AIC=1030.981, Time=0.72 sec
#  ARIMA(13,1,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.58 sec
#  ARIMA(13,1,1)(0,0,0)[0] intercept   : AIC=1019.072, Time=0.60 sec
#  ARIMA(13,1,2)(0,0,0)[0] intercept   : AIC=1021.041, Time=0.62 sec
#  ARIMA(13,1,3)(0,0,0)[0] intercept   : AIC=1021.921, Time=0.70 sec
#  ARIMA(13,1,4)(0,0,0)[0] intercept   : AIC=1022.414, Time=0.71 sec
#  ARIMA(13,1,5)(0,0,0)[0] intercept   : AIC=1024.156, Time=0.73 sec
#  ARIMA(13,1,6)(0,0,0)[0] intercept   : AIC=1024.879, Time=0.76 sec
#  ARIMA(13,1,7)(0,0,0)[0] intercept   : AIC=1026.609, Time=0.86 sec
#  ARIMA(13,1,8)(0,0,0)[0] intercept   : AIC=1028.430, Time=0.83 sec
#  ARIMA(13,1,9)(0,0,0)[0] intercept   : AIC=1029.836, Time=0.78 sec
#  ARIMA(13,1,10)(0,0,0)[0] intercept   : AIC=inf, Time=1.02 sec
#  ARIMA(14,1,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.61 sec
#  ARIMA(14,1,1)(0,0,0)[0] intercept   : AIC=1019.042, Time=0.70 sec
#  ARIMA(14,1,2)(0,0,0)[0] intercept   : AIC=1020.284, Time=0.73 sec
#  ARIMA(14,1,3)(0,0,0)[0] intercept   : AIC=1022.354, Time=0.70 sec
#  ARIMA(14,1,4)(0,0,0)[0] intercept   : AIC=1024.146, Time=0.81 sec
#  ARIMA(14,1,5)(0,0,0)[0] intercept   : AIC=1024.142, Time=0.70 sec
#  ARIMA(14,1,6)(0,0,0)[0] intercept   : AIC=1025.672, Time=1.34 sec
#  ARIMA(14,1,7)(0,0,0)[0] intercept   : AIC=1027.334, Time=1.05 sec
#  ARIMA(14,1,8)(0,0,0)[0] intercept   : AIC=1028.900, Time=0.92 sec
#  ARIMA(14,1,9)(0,0,0)[0] intercept   : AIC=1028.492, Time=1.01 sec
#  ARIMA(14,1,10)(0,0,0)[0] intercept   : AIC=1029.854, Time=1.08 sec
#  ARIMA(15,1,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.73 sec
#  ARIMA(15,1,1)(0,0,0)[0] intercept   : AIC=1020.473, Time=0.67 sec
#  ARIMA(15,1,2)(0,0,0)[0] intercept   : AIC=1022.207, Time=0.79 sec
#  ARIMA(15,1,3)(0,0,0)[0] intercept   : AIC=1024.553, Time=0.77 sec
#  ARIMA(15,1,4)(0,0,0)[0] intercept   : AIC=1026.017, Time=0.83 sec
#  ARIMA(15,1,5)(0,0,0)[0] intercept   : AIC=1025.510, Time=0.76 sec
#  ARIMA(15,1,6)(0,0,0)[0] intercept   : AIC=1027.864, Time=1.05 sec
#  ARIMA(15,1,7)(0,0,0)[0] intercept   : AIC=1029.650, Time=1.22 sec
#  ARIMA(15,1,8)(0,0,0)[0] intercept   : AIC=1032.273, Time=1.40 sec
#  ARIMA(15,1,9)(0,0,0)[0] intercept   : AIC=1029.742, Time=1.32 sec
#  ARIMA(15,1,10)(0,0,0)[0] intercept   : AIC=1031.808, Time=1.47 sec
#
# Best model:  ARIMA(14,1,1)(0,0,0)[0] intercept
# Total fit time: 72.469 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  132
# Model:              SARIMAX(14, 1, 1)   Log Likelihood                -492.521
# Date:                Sat, 12 Oct 2024   AIC                           1019.042
# Time:                        15:05:19   BIC                           1067.920
# Sample:                    01-01-1949   HQIC                          1038.903
#                          - 12-01-1959
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      5.0337      2.976      1.692      0.091      -0.799      10.866
# ar.L1         -0.3796      0.567     -0.670      0.503      -1.491       0.731
# ar.L2         -0.0819      0.193     -0.425      0.671      -0.460       0.296
# ar.L3         -0.1187      0.124     -0.958      0.338      -0.362       0.124
# ar.L4         -0.2434      0.084     -2.909      0.004      -0.407      -0.079
# ar.L5         -0.0789      0.126     -0.626      0.532      -0.326       0.168
# ar.L6         -0.2425      0.084     -2.897      0.004      -0.407      -0.078
# ar.L7         -0.1029      0.135     -0.762      0.446      -0.368       0.162
# ar.L8         -0.2556      0.091     -2.807      0.005      -0.434      -0.077
# ar.L9         -0.0834      0.142     -0.589      0.556      -0.361       0.194
# ar.L10        -0.2528      0.093     -2.722      0.006      -0.435      -0.071
# ar.L11        -0.0730      0.153     -0.477      0.633      -0.373       0.227
# ar.L12         0.7008      0.085      8.246      0.000       0.534       0.867
# ar.L13         0.3005      0.437      0.687      0.492      -0.557       1.158
# ar.L14        -0.1531      0.200     -0.766      0.444      -0.545       0.239
# ma.L1          0.1864      0.595      0.313      0.754      -0.979       1.352
# sigma2        91.3279     14.162      6.449      0.000      63.572     119.084
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                14.43
# Prob(Q):                              0.90   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.09   Skew:                            -0.20
# Prob(H) (two-sided):                  0.02   Kurtosis:                         4.58
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# * The best model here is ARIMA(14, 1, 1). Let's check its performance metrics.

# %%
evaluate_model(train_actual4, train_pred4)
# Out:
# {'MAE': 7.746827,
#  'MSE': 98.259867,
#  'RMSE': 9.912612,
#  'MAPE': 3.385423,
#  'R²': 0.991223}

# %%
evaluate_model(test_actual4, test_pred4)
# Out:
# {'MAE': 14.969064,
#  'MSE': 330.736625,
#  'RMSE': 18.186166,
#  'MAPE': 3.100583,
#  'R²': 0.940295}

# %%
train_actual5, train_pred5, test_actual5, test_pred5 = auto_sarima_split(df2, 'LogPassengers', 
                                                                            Ntest = 12, 
                                                                            seasonal=False,
                                                                            stepwise = False, # Full Grid Search
                                                                            y_name='LogPassengers')
# Out:
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-211.983, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-216.493, Time=0.02 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.04 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(0,1,5)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(0,1,6)(0,0,0)[0] intercept   : AIC=-261.214, Time=0.12 sec
#  ARIMA(0,1,7)(0,0,0)[0] intercept   : AIC=-260.014, Time=0.15 sec
#  ARIMA(0,1,8)(0,0,0)[0] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(0,1,9)(0,0,0)[0] intercept   : AIC=-265.379, Time=0.29 sec
#  ARIMA(0,1,10)(0,0,0)[0] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-214.718, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-221.069, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=-252.224, Time=0.10 sec
#  ARIMA(1,1,5)(0,0,0)[0] intercept   : AIC=-261.253, Time=0.13 sec
#  ARIMA(1,1,6)(0,0,0)[0] intercept   : AIC=-259.890, Time=0.13 sec
#  ARIMA(1,1,7)(0,0,0)[0] intercept   : AIC=-257.083, Time=0.18 sec
#  ARIMA(1,1,8)(0,0,0)[0] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(1,1,9)(0,0,0)[0] intercept   : AIC=-275.472, Time=0.35 sec
#  ARIMA(1,1,10)(0,0,0)[0] intercept   : AIC=inf, Time=0.45 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=-216.622, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-237.759, Time=0.11 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(2,1,5)(0,0,0)[0] intercept   : AIC=-253.208, Time=0.18 sec
#  ARIMA(2,1,6)(0,0,0)[0] intercept   : AIC=-244.340, Time=0.14 sec
#  ARIMA(2,1,7)(0,0,0)[0] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(2,1,8)(0,0,0)[0] intercept   : AIC=-257.610, Time=0.23 sec
#  ARIMA(2,1,9)(0,0,0)[0] intercept   : AIC=-273.180, Time=0.28 sec
#  ARIMA(2,1,10)(0,0,0)[0] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=-216.024, Time=0.04 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-246.300, Time=0.10 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=-251.099, Time=0.09 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=-253.557, Time=0.09 sec
#  ARIMA(3,1,5)(0,0,0)[0] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(3,1,6)(0,0,0)[0] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(3,1,7)(0,0,0)[0] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(3,1,8)(0,0,0)[0] intercept   : AIC=-261.622, Time=0.24 sec
#  ARIMA(3,1,9)(0,0,0)[0] intercept   : AIC=-271.357, Time=0.31 sec
#  ARIMA(3,1,10)(0,0,0)[0] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=-229.057, Time=0.07 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=-227.139, Time=0.11 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=-250.921, Time=0.13 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(4,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(4,1,5)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(4,1,6)(0,0,0)[0] intercept   : AIC=-254.249, Time=0.16 sec
#  ARIMA(4,1,7)(0,0,0)[0] intercept   : AIC=-267.334, Time=0.23 sec
#  ARIMA(4,1,8)(0,0,0)[0] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(4,1,9)(0,0,0)[0] intercept   : AIC=-309.073, Time=0.39 sec
#  ARIMA(4,1,10)(0,0,0)[0] intercept   : AIC=-293.972, Time=0.58 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=-227.112, Time=0.08 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=-226.803, Time=0.18 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=-250.075, Time=0.09 sec
#  ARIMA(5,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(5,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(5,1,5)(0,0,0)[0] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(5,1,6)(0,0,0)[0] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(5,1,7)(0,0,0)[0] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(5,1,8)(0,0,0)[0] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(5,1,9)(0,0,0)[0] intercept   : AIC=-304.395, Time=0.44 sec
#  ARIMA(5,1,10)(0,0,0)[0] intercept   : AIC=-304.291, Time=0.67 sec
#  ARIMA(6,1,0)(0,0,0)[0] intercept   : AIC=-225.728, Time=0.08 sec
#  ARIMA(6,1,1)(0,0,0)[0] intercept   : AIC=-248.955, Time=0.21 sec
#  ARIMA(6,1,2)(0,0,0)[0] intercept   : AIC=-247.999, Time=0.19 sec
#  ARIMA(6,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(6,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(6,1,5)(0,0,0)[0] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(6,1,6)(0,0,0)[0] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(6,1,7)(0,0,0)[0] intercept   : AIC=-268.168, Time=0.27 sec
#  ARIMA(6,1,8)(0,0,0)[0] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(6,1,9)(0,0,0)[0] intercept   : AIC=-302.148, Time=0.38 sec
#  ARIMA(6,1,10)(0,0,0)[0] intercept   : AIC=inf, Time=0.55 sec
#  ARIMA(7,1,0)(0,0,0)[0] intercept   : AIC=-228.979, Time=0.11 sec
#  ARIMA(7,1,1)(0,0,0)[0] intercept   : AIC=-270.763, Time=0.20 sec
#  ARIMA(7,1,2)(0,0,0)[0] intercept   : AIC=-252.269, Time=0.16 sec
#  ARIMA(7,1,3)(0,0,0)[0] intercept   : AIC=-245.950, Time=0.17 sec
#  ARIMA(7,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(7,1,5)(0,0,0)[0] intercept   : AIC=-268.128, Time=0.22 sec
#  ARIMA(7,1,6)(0,0,0)[0] intercept   : AIC=-299.064, Time=0.23 sec
#  ARIMA(7,1,7)(0,0,0)[0] intercept   : AIC=-312.444, Time=0.30 sec
#  ARIMA(7,1,8)(0,0,0)[0] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(7,1,9)(0,0,0)[0] intercept   : AIC=-317.294, Time=0.44 sec
#  ARIMA(7,1,10)(0,0,0)[0] intercept   : AIC=-308.425, Time=0.59 sec
#  ARIMA(8,1,0)(0,0,0)[0] intercept   : AIC=-271.247, Time=0.28 sec
#  ARIMA(8,1,1)(0,0,0)[0] intercept   : AIC=-298.937, Time=0.28 sec
#  ARIMA(8,1,2)(0,0,0)[0] intercept   : AIC=-294.982, Time=0.23 sec
#  ARIMA(8,1,3)(0,0,0)[0] intercept   : AIC=-301.616, Time=0.24 sec
#  ARIMA(8,1,4)(0,0,0)[0] intercept   : AIC=-340.936, Time=0.29 sec
#  ARIMA(8,1,5)(0,0,0)[0] intercept   : AIC=-336.406, Time=0.27 sec
#  ARIMA(8,1,6)(0,0,0)[0] intercept   : AIC=-352.785, Time=0.28 sec
#  ARIMA(8,1,7)(0,0,0)[0] intercept   : AIC=-352.034, Time=0.30 sec
#  ARIMA(8,1,8)(0,0,0)[0] intercept   : AIC=-379.137, Time=0.37 sec
#  ARIMA(8,1,9)(0,0,0)[0] intercept   : AIC=-367.690, Time=0.45 sec
#  ARIMA(8,1,10)(0,0,0)[0] intercept   : AIC=inf, Time=0.58 sec
#  ARIMA(9,1,0)(0,0,0)[0] intercept   : AIC=-274.932, Time=0.33 sec
#  ARIMA(9,1,1)(0,0,0)[0] intercept   : AIC=-298.948, Time=0.25 sec
#  ARIMA(9,1,2)(0,0,0)[0] intercept   : AIC=-295.939, Time=0.26 sec
#  ARIMA(9,1,3)(0,0,0)[0] intercept   : AIC=-326.777, Time=0.27 sec
#  ARIMA(9,1,4)(0,0,0)[0] intercept   : AIC=-345.303, Time=0.35 sec
#  ARIMA(9,1,5)(0,0,0)[0] intercept   : AIC=-339.449, Time=0.33 sec
#  ARIMA(9,1,6)(0,0,0)[0] intercept   : AIC=-348.739, Time=0.32 sec
#  ARIMA(9,1,7)(0,0,0)[0] intercept   : AIC=-352.698, Time=0.38 sec
#  ARIMA(9,1,8)(0,0,0)[0] intercept   : AIC=-377.186, Time=0.43 sec
#  ARIMA(9,1,9)(0,0,0)[0] intercept   : AIC=-367.371, Time=0.45 sec
#  ARIMA(9,1,10)(0,0,0)[0] intercept   : AIC=inf, Time=0.64 sec
#  ARIMA(10,1,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(10,1,1)(0,0,0)[0] intercept   : AIC=-343.928, Time=0.31 sec
#  ARIMA(10,1,2)(0,0,0)[0] intercept   : AIC=-364.865, Time=0.36 sec
#  ARIMA(10,1,3)(0,0,0)[0] intercept   : AIC=-355.349, Time=0.40 sec
#  ARIMA(10,1,4)(0,0,0)[0] intercept   : AIC=-396.452, Time=0.41 sec
#  ARIMA(10,1,5)(0,0,0)[0] intercept   : AIC=-392.598, Time=0.45 sec
#  ARIMA(10,1,6)(0,0,0)[0] intercept   : AIC=-417.922, Time=0.43 sec
#  ARIMA(10,1,7)(0,0,0)[0] intercept   : AIC=-418.415, Time=0.44 sec
#  ARIMA(10,1,8)(0,0,0)[0] intercept   : AIC=-418.852, Time=0.51 sec
#  ARIMA(10,1,9)(0,0,0)[0] intercept   : AIC=inf, Time=0.58 sec
#  ARIMA(10,1,10)(0,0,0)[0] intercept   : AIC=-385.825, Time=0.76 sec
#  ARIMA(11,1,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.43 sec
#  ARIMA(11,1,1)(0,0,0)[0] intercept   : AIC=-378.007, Time=0.52 sec
#  ARIMA(11,1,2)(0,0,0)[0] intercept   : AIC=-411.997, Time=0.52 sec
#  ARIMA(11,1,3)(0,0,0)[0] intercept   : AIC=-413.132, Time=0.63 sec
#  ARIMA(11,1,4)(0,0,0)[0] intercept   : AIC=-417.087, Time=0.58 sec
#  ARIMA(11,1,5)(0,0,0)[0] intercept   : AIC=-417.379, Time=0.63 sec
#  ARIMA(11,1,6)(0,0,0)[0] intercept   : AIC=-422.844, Time=0.60 sec
#  ARIMA(11,1,7)(0,0,0)[0] intercept   : AIC=-418.600, Time=0.62 sec
#  ARIMA(11,1,8)(0,0,0)[0] intercept   : AIC=-411.120, Time=0.84 sec
#  ARIMA(11,1,9)(0,0,0)[0] intercept   : AIC=-379.907, Time=0.87 sec
#  ARIMA(11,1,10)(0,0,0)[0] intercept   : AIC=-420.560, Time=0.88 sec
#  ARIMA(12,1,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.43 sec
#  ARIMA(12,1,1)(0,0,0)[0] intercept   : AIC=-423.759, Time=0.55 sec
#  ARIMA(12,1,2)(0,0,0)[0] intercept   : AIC=-417.371, Time=0.89 sec
#  ARIMA(12,1,3)(0,0,0)[0] intercept   : AIC=-422.642, Time=0.96 sec
#  ARIMA(12,1,4)(0,0,0)[0] intercept   : AIC=-419.601, Time=0.69 sec
#  ARIMA(12,1,5)(0,0,0)[0] intercept   : AIC=-406.709, Time=0.77 sec
#  ARIMA(12,1,6)(0,0,0)[0] intercept   : AIC=-416.783, Time=1.03 sec
#  ARIMA(12,1,7)(0,0,0)[0] intercept   : AIC=-417.311, Time=0.90 sec
#  ARIMA(12,1,8)(0,0,0)[0] intercept   : AIC=-410.446, Time=1.20 sec
#  ARIMA(12,1,9)(0,0,0)[0] intercept   : AIC=-395.724, Time=1.02 sec
#  ARIMA(12,1,10)(0,0,0)[0] intercept   : AIC=-407.214, Time=0.95 sec
#  ARIMA(13,1,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.56 sec
#  ARIMA(13,1,1)(0,0,0)[0] intercept   : AIC=-420.071, Time=0.61 sec
#  ARIMA(13,1,2)(0,0,0)[0] intercept   : AIC=-418.044, Time=0.76 sec
#  ARIMA(13,1,3)(0,0,0)[0] intercept   : AIC=-422.905, Time=0.84 sec
#  ARIMA(13,1,4)(0,0,0)[0] intercept   : AIC=-420.154, Time=0.80 sec
#  ARIMA(13,1,5)(0,0,0)[0] intercept   : AIC=-397.330, Time=0.82 sec
#  ARIMA(13,1,6)(0,0,0)[0] intercept   : AIC=-415.298, Time=0.82 sec
#  ARIMA(13,1,7)(0,0,0)[0] intercept   : AIC=-412.250, Time=1.03 sec
#  ARIMA(13,1,8)(0,0,0)[0] intercept   : AIC=-407.509, Time=1.07 sec
#  ARIMA(13,1,9)(0,0,0)[0] intercept   : AIC=-408.947, Time=1.06 sec
#  ARIMA(13,1,10)(0,0,0)[0] intercept   : AIC=-408.285, Time=1.14 sec
#  ARIMA(14,1,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.71 sec
#  ARIMA(14,1,1)(0,0,0)[0] intercept   : AIC=-418.957, Time=0.81 sec
#  ARIMA(14,1,2)(0,0,0)[0] intercept   : AIC=-425.200, Time=0.93 sec
#  ARIMA(14,1,3)(0,0,0)[0] intercept   : AIC=-423.452, Time=1.08 sec
#  ARIMA(14,1,4)(0,0,0)[0] intercept   : AIC=-420.946, Time=0.93 sec
#  ARIMA(14,1,5)(0,0,0)[0] intercept   : AIC=-393.602, Time=0.99 sec
#  ARIMA(14,1,6)(0,0,0)[0] intercept   : AIC=-406.699, Time=1.08 sec
#  ARIMA(14,1,7)(0,0,0)[0] intercept   : AIC=-415.886, Time=1.15 sec
#  ARIMA(14,1,8)(0,0,0)[0] intercept   : AIC=-412.468, Time=1.15 sec
#  ARIMA(14,1,9)(0,0,0)[0] intercept   : AIC=-410.731, Time=1.24 sec
#  ARIMA(14,1,10)(0,0,0)[0] intercept   : AIC=-405.825, Time=1.14 sec
#  ARIMA(15,1,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(15,1,1)(0,0,0)[0] intercept   : AIC=-423.383, Time=1.06 sec
#  ARIMA(15,1,2)(0,0,0)[0] intercept   : AIC=-423.131, Time=1.00 sec
#  ARIMA(15,1,3)(0,0,0)[0] intercept   : AIC=-419.838, Time=0.96 sec
#  ARIMA(15,1,4)(0,0,0)[0] intercept   : AIC=-417.591, Time=0.97 sec
#  ARIMA(15,1,5)(0,0,0)[0] intercept   : AIC=-414.280, Time=1.09 sec
#  ARIMA(15,1,6)(0,0,0)[0] intercept   : AIC=-409.938, Time=1.03 sec
#  ARIMA(15,1,7)(0,0,0)[0] intercept   : AIC=-414.278, Time=1.06 sec
#  ARIMA(15,1,8)(0,0,0)[0] intercept   : AIC=-409.744, Time=1.29 sec
#  ARIMA(15,1,9)(0,0,0)[0] intercept   : AIC=-407.734, Time=1.27 sec
#  ARIMA(15,1,10)(0,0,0)[0] intercept   : AIC=-406.696, Time=1.34 sec
#
# Best model:  ARIMA(14,1,2)(0,0,0)[0] intercept
# Total fit time: 79.502 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  132
# Model:              SARIMAX(14, 1, 2)   Log Likelihood                 230.600
# Date:                Sat, 12 Oct 2024   AIC                           -425.200
# Time:                        15:06:39   BIC                           -373.447
# Sample:                    01-01-1949   HQIC                          -404.171
#                          - 12-01-1959
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0036      0.008      0.434      0.665      -0.013       0.020
# ar.L1         -0.1723      0.608     -0.284      0.777      -1.364       1.019
# ar.L2          0.2968      0.363      0.818      0.413      -0.414       1.008
# ar.L3         -0.0003      0.100     -0.003      0.998      -0.197       0.196
# ar.L4         -0.0966      0.063     -1.536      0.124      -0.220       0.027
# ar.L5          0.0578      0.121      0.476      0.634      -0.180       0.295
# ar.L6         -0.0451      0.064     -0.703      0.482      -0.171       0.081
# ar.L7         -0.0311      0.082     -0.379      0.705      -0.192       0.130
# ar.L8         -0.1077      0.074     -1.458      0.145      -0.252       0.037
# ar.L9          0.0596      0.123      0.484      0.628      -0.182       0.301
# ar.L10        -0.0686      0.071     -0.964      0.335      -0.208       0.071
# ar.L11         0.0431      0.095      0.453      0.650      -0.143       0.230
# ar.L12         0.8171      0.068     11.964      0.000       0.683       0.951
# ar.L13         0.2548      0.468      0.545      0.586      -0.662       1.171
# ar.L14        -0.3675      0.349     -1.052      0.293      -1.052       0.317
# ma.L1         -0.1233      0.597     -0.207      0.836      -1.293       1.046
# ma.L2         -0.4007      0.231     -1.734      0.083      -0.854       0.052
# sigma2         0.0014      0.000      6.867      0.000       0.001       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.97
# Prob(Q):                              0.95   Prob(JB):                         0.61
# Heteroskedasticity (H):               0.39   Skew:                             0.18
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.20
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
evaluate_model(train_actual5, train_pred5, is_logged = True)
# Out:
# {'MAE': 7.864719,
#  'MSE': 97.14651,
#  'RMSE': 9.856293,
#  'MAPE': 3.371767,
#  'R²': 0.991322}

# %%
evaluate_model(test_actual5, test_pred5, is_logged = True)
# Out:
# {'MAE': 21.736753,
#  'MSE': 641.770375,
#  'RMSE': 25.333187,
#  'MAPE': 4.726859,
#  'R²': 0.884146}

# %% [markdown]
# * Although the real practice should be more thorough, by these examples, we can see that:
# 1) By applying fundamental techniques of Stationarity Test, ACF, PACF plot, we can still choose a decent model compared to the Auto processes.
# 2) More practice can be done by comparing these to the Naive forecast model.
# 3) More practice can be implemented by applying more sophisticated techniques.
